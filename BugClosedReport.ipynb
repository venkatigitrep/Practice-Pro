# %% [raw]
# Resource wise Closed Bugs - Report
# """
# Created on Mon Apr 13 14:30:09 2020
#
# @author: venkati.naidu
# """

# %%
import pandas as pd
import numpy as mp
import random
from matplotlib import pyplot
pd.set_option('colheader_justify', 'left')   # FOR TABLE <th>

# %%
def color_format(value):
    """
    Colors scheme can be changed
    """

    if value == "Active" or value == "High":
        color = 'red'
    elif value == "Closed":
        color = 'green'
    elif value == "In Test" or value == 'Resolved':
        color = 'orange'
    elif value == 'Medium':
        color = '#bf00ff'
    elif value == 'Low':
        color = '#00c0ff'
    elif value == 'Deferred':
        color = 'blue'
    else:
        color = 'black'

          
    return 'font-size:11pt; font-family: Arial;border-collapse: collapse;border: 1px solid silver;text-align: left; color: %s' % color

# %%
def Generate_Status_Report():
    
    includeClosedBugs = True
    
    df_bugs = pd.read_csv('February Release - All bugs.csv', 
                          usecols=['Iteration Path','State','Severity','Closed By','Created By'])[['Iteration Path','State','Severity','Closed By','Created By']]
    df_bugs["Iteration Path"] = df_bugs["Iteration Path"].str.split('\\').str[-1]
    df_bugs.Severity = df_bugs["Severity"].str.split('- ').str[-1]
    
    #Filtering the closed records
    if not includeClosedBugs:
        print("Note: Excluded the Closed bugs")
        df_bugs = df_bugs[(df_bugs.State != 'Closed')]       
    
    #State_n_Severity_ExcludingClosed =df_bugs.groupby(["Iteration Path", "State","Severity"])["Severity"].count() #.size()
    State_n_Severity = df_bugs.groupby(["Iteration Path", "Created By","State"]).agg(Bug_Count=pd.NamedAgg(column="State", aggfunc="count"))
       
    return State_n_Severity

PrintReport = Generate_Status_Report()

# %%
tbl = PrintReport.reset_index()
tbl[['Iteration Path']] = tbl[["Iteration Path"]].where(tbl[["Iteration Path"]]. \
                                                        apply(lambda ip: ip != ip.shift()), '')
tbl[['Created By']] = tbl[["Created By"]].where(tbl[["Created By"]]. \
                                                        apply(lambda ip: ip != ip.shift()), '')
tbl.style.applymap(color_format)
# Out:
# <style  type="text/css" >
#     #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row0_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row0_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row0_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  green;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row0_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row1_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row1_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row1_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  green;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row1_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row2_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row2_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row2_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  green;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row2_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row3_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row3_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row3_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  green;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row3_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row4_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row4_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row4_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  blue;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row4_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row5_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row5_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row5_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  green;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row5_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row6_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row6_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row6_col2 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  green;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row6_col3 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row7_col0 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea_84e5_d8f2ca8b5366row7_col1 {
#             font-size: 11pt;
#              font-family:  Arial;
#             border-collapse:  collapse;
#             border:  1px solid silver;
#             text-align:  left;
#              color:  black;
#         }    #T_c42601cc_7f13_11ea

# %% [markdown]
# <h1>Convert the Bug Report into HTML </h1>

# %%
pd.set_option('colheader_justify', 'left')   # FOR TABLE <th>

html_string = '''
<html>

  <head><title>HTML Pandas Dataframe with CSS</title></head>
  <link rel="stylesheet" type="text/css" href="df_style.css"/>
  <body>
  <h1> Bugs Closed - Report </h1>
    {table}
  </body>
</html>.
'''

# OUTPUT AN HTML FILE
with open('myhtml.html', 'w') as f:
    f.write(html_string.format(table=tbl.to_html(classes='mystyle')))
